# %%
import nltk
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import pos_tag

# Download required resources (run once)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Sagar
# [nltk_data]     Sharma\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Sagar
# [nltk_data]     Sharma\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Sagar Sharma\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to C:\Users\Sagar
# [nltk_data]     Sharma\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
text = "Natural Language Processing is a fascinating field of Artificial Intelligence. It helps computers understand human language."

# %%
tokens = word_tokenize(text)
print("Tokens:", tokens)
# Out:
# Tokens: ['Natural', 'Language', 'Processing', 'is', 'a', 'fascinating', 'field', 'of', 'Artificial', 'Intelligence', '.', 'It', 'helps', 'computers', 'understand', 'human', 'language', '.']

# %%
pos_tags = pos_tag(tokens)
print("POS Tags:", pos_tags)
# Out:
# POS Tags: [('Natural', 'JJ'), ('Language', 'NNP'), ('Processing', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('fascinating', 'JJ'), ('field', 'NN'), ('of', 'IN'), ('Artificial', 'JJ'), ('Intelligence', 'NNP'), ('.', '.'), ('It', 'PRP'), ('helps', 'VBZ'), ('computers', 'NNS'), ('understand', 'VBP'), ('human', 'JJ'), ('language', 'NN'), ('.', '.')]

# %%
stop_words = set(stopwords.words("english"))

filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

print("After Stopword Removal:", filtered_tokens)
# Out:
# After Stopword Removal: ['Natural', 'Language', 'Processing', 'fascinating', 'field', 'Artificial', 'Intelligence', '.', 'helps', 'computers', 'understand', 'human', 'language', '.']

# %%
stemmer = PorterStemmer()

stemmed = [stemmer.stem(word) for word in filtered_tokens]

print("Stemmed:", stemmed)
# Out:
# Stemmed: ['natur', 'languag', 'process', 'fascin', 'field', 'artifici', 'intellig', '.', 'help', 'comput', 'understand', 'human', 'languag', '.']

# %%
lemmatizer = WordNetLemmatizer()

lemmatized = [lemmatizer.lemmatize(word) for word in filtered_tokens]

print("Lemmatized:", lemmatized)
# Out:
# Lemmatized: ['Natural', 'Language', 'Processing', 'fascinating', 'field', 'Artificial', 'Intelligence', '.', 'help', 'computer', 'understand', 'human', 'language', '.']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "Natural Language Processing is fascinating",
    "Artificial Intelligence helps machines understand language",
    text
]

vectorizer = TfidfVectorizer()

tfidf_matrix = vectorizer.fit_transform(documents)

feature_names = vectorizer.get_feature_names_out()

tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)

print(tfidf_df)
# Out:
#    artificial  computers  fascinating     field     helps     human  \
# 0    0.000000   0.000000     0.466096  0.000000  0.000000  0.000000
# 1    0.397402   0.000000     0.000000  0.000000  0.397402  0.000000
# 2    0.229073   0.301203     0.229073  0.301203  0.229073  0.301203
#
#    intelligence        is        it  language  machines   natural        of  \
# 0      0.000000  0.466096  0.000000  0.361965  0.000000  0.466096  0.000000
# 1      0.397402  0.000000  0.000000  0.308618  0.522535  0.000000  0.000000
# 2      0.229073  0.229073  0.301203  0.355791  0.000000  0.229073  0.301203
#
#    processing  understand
# 0    0.466096    0.000000
# 1    0.000000    0.397402
# 2    0.229073    0.229073
